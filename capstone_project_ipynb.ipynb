# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("Capstone Project - Data Analysis")
data = {
    'Experience': [1,2,3,4,5],
    'Salary': [30000,40000,50000,60000,70000]
}

df = pd.DataFrame(data)
print(df)
plt.plot(df['Experience'], df['Salary'])
plt.title("Experience vs Salary")
plt.show()
# Out:
# Capstone Project - Data Analysis
#    Experience  Salary
# 0           1   30000
# 1           2   40000
# 2           3   50000
# 3           4   60000
# 4           5   70000
